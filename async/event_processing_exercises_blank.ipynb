# %% [markdown]
# # 30 Event‑Processing Interview Problems (Stdlib‑Only, **No Solutions**)
#
# Each section poses a realistic *events‑in‑memory* challenge you might face in a 60‑minute coding interview.
# For every problem you get:
#
# * **Problem statement** – what to build.
# * **Hint** – the *one or two* Python‑stdlib constructs you’ll probably need (from the cheat‑sheet).
# * **Starter cell** – write your own code below the `# TODO` line.
#
# > ✨ **Pro tip:** run `help(<obj>)` in a separate cell if you forget an API.

# %% [markdown]
# ## Helper – Synthetic Event Generator
#
# You can reuse this if you like, or roll your own. Delete or modify as you wish.

# %%
import random, string
from datetime import datetime, timedelta

random.seed(42)
EVENT_TYPES = ["CLICK", "VIEW", "LOGIN", "PURCHASE", "LOGOUT"]

def random_timestamp(start, end):
    delta = end - start
    return start + timedelta(seconds=random.randint(0, int(delta.total_seconds())))

def generate_events(n=1000):
    start = datetime.now() - timedelta(days=100)
    end = datetime.now()
    for i in range(n):
        yield {
            "id": i,
            "ts": random_timestamp(start, end).isoformat(),
            "user": f"user{random.randint(1, 50)}",
            "type": random.choice(EVENT_TYPES),
            "payload": {"value": random.randint(1, 1000)}
        }

# %% [markdown]
# ---
#
# ### Problem 1 – Top‑K Event Types
#
# **Task**
# Top‑K Event Types.
#
# **Hint (constructs to consider)** → collections.Counter, heapq.nlargest

# %%
from collections import Counter
# ⬇️ Write your solution for Problem 1 below

g = generate_events()
c = Counter()
for event in g:
    # iterable of one
    c.update([event["type"]])

c.most_common(2)
# Out:
# [('LOGOUT', 208), ('PURCHASE', 204)]

# %%
import heapq

h = []
g = generate_events(1000)
for d in g:
    heapq.heappush(h, ((d["ts"]), d))

# %%
# Ascending Time

tsl = [heapq.heappop(h) for _ in h]
tsl[:2]
# Out:
# [('2025-03-04T08:57:34.517168',
#   {'id': 203,
#    'ts': '2025-03-04T08:57:34.517168',
#    'user': 'user6',
#    'type': 'LOGOUT',
#    'payload': {'value': 987}}),
#  ('2025-03-04T13:45:43.517168',
#   {'id': 363,
#    'ts': '2025-03-04T13:45:43.517168',
#    'user': 'user50',
#    'type': 'PURCHASE',
#    'payload': {'value': 535}})]

# %%
# Descending Time 

sorted(tsl, reverse=True)[:2]
# Out:
# [('2025-04-22T11:45:04.517168',
#   {'id': 682,
#    'ts': '2025-04-22T11:45:04.517168',
#    'user': 'user1',
#    'type': 'PURCHASE',
#    'payload': {'value': 510}}),
#  ('2025-04-22T04:55:43.517168',
#   {'id': 466,
#    'ts': '2025-04-22T04:55:43.517168',
#    'user': 'user48',
#    'type': 'CLICK',
#    'payload': {'value': 216}})]

# %% [markdown]
# ---
#
# ### Problem 2 – Per‑User Sliding‑Window Rate Limiter
#
# **Task**
# Per‑User Sliding‑Window Rate Limiter.
#
# **Hint (constructs to consider)** → collections.defaultdict, collections.deque

# %%
from collections import deque
# ⬇️ Write your solution for Problem 2 below
USER = "user5"
g = generate_events(1000)
d = deque(maxlen=100)
for elem in generate_events(1000):
    if d.count(USER) >= 2:
        print(f"{USER} reached his limit")
        continue
    d.appendleft(elem["user"])
# Out:
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit
# user5 reached his limit

# %%
# Moving Average
g = generate_events(1000)
d = deque(maxlen=100)
s = 0
for elem in generate_events(1000):
    d.appendleft(elem["user"])

# %%
def moving_average():
    g = generate_events(100)
    d = deque()
    count = 0
    s = 0
    for elem in g:
        if count == 10:
            count -= 1
            s -= d.pop()     
        payload = elem["payload"]["value"]
        d.appendleft(elem["payload"]["value"])
        count += 1
        s += payload
        mv = s/count
        yield mv, count

# %%
list(moving_average())
# Out:
# [(599.0, 1),
#  (634.5, 2),
#  (739.0, 3),
#  (593.5, 4),
#  (517.2, 5),
#  (435.5, 6),
#  (452.42857142857144, 7),
#  (507.375, 8),
#  (474.0, 9),
#  (454.4, 10),
#  (397.3, 10),
#  (415.8, 10),
#  (409.9, 10),
#  (440.0, 10),
#  (439.9, 10),
#  (446.8, 10),
#  (465.6, 10),
#  (388.8, 10),
#  (404.8, 10),
#  (398.6, 10),
#  (444.8, 10),
#  (456.1, 10),
#  (406.2, 10),
#  (396.8, 10),
#  (420.2, 10),
#  (477.3, 10),
#  (500.6, 10),
#  (492.9, 10),
#  (514.1, 10),
#  (508.5, 10),
#  (537.6, 10),
#  (523.0, 10),
#  (522.1, 10),
#  (503.4, 10),
#  (534.9, 10),
#  (548.8, 10),
#  (472.2, 10),
#  (560.6, 10),
#  (505.7, 10),
#  (580.8, 10),
#  (596.3, 10),
#  (552.8, 10),
#  (516.3, 10),
#  (541.6, 10),
#  (513.2, 10),
#  (446.4, 10),
#  (473.6, 10),
#  (447.8, 10),
#  (493.8, 10),
#  (422.8, 10),
#  (342.5, 10),
#  (380.0, 10),
#  (407.4, 10),
#  (390.1, 10),
#  (376.2, 10),
#  (415.7, 10),
#  (401.2, 10),
#  (393.3, 10),
#  (409.1, 10),
#  (390.5, 10),
#  (462.8, 10),
#  (419.7, 10),
#  (440.3, 10),
#  (456.2, 10),
#  (486.2, 10),
#  (445.0, 10),
#  (506.1, 10),
#  (472.9, 10),
#  (454.9, 10),
#  (531.6, 10),
#  (489.7, 10),
#  (466.3, 10),
#  (429.1, 10),
#  (419.0, 10),
#  (451.6, 10),
#  (480.3, 10),
#  (471.7, 10),
#  (465.9, 10),
#  (499.0, 10),
#  (474.6, 10),
#  (486.2, 10),
#  (493.6, 10),
#  (550.9, 10),
#  (542.6, 10),
#  (489.8, 10),
#  (547.3, 10),
#  (553.5, 10),
#  (566.1, 10),
#  (486.3, 10),
#  (501.0, 10),
#  (506.6, 10),
#  (503.9, 10),
#  (512.5, 10),
#  (555.5, 10),
#  (531.9, 10),
#  (456.8, 10),
#  (377.2, 10),
#  (358.8, 10),
#  (359.9, 10),
#  (345.1, 10)]

# %% [markdown]
# ---
#
# ### Problem 3 – LRU Cache for Expensive Payload Transforms
#
# **Task**
# LRU Cache for Expensive Payload Transforms.
#
# **Hint (constructs to consider)** → collections.OrderedDict

# %%
# ⬇️ Write your solution for Problem 3 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 4 – Merge K Pre‑sorted Event Streams by Timestamp
#
# **Task**
# Merge K Pre‑sorted Event Streams by Timestamp.
#
# **Hint (constructs to consider)** → heapq.merge

# %%
# ⬇️ Write your solution for Problem 4 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 5 – Count Events in Last W Seconds Using Binary Search
#
# **Task**
# Count Events in Last W Seconds Using Binary Search.
#
# **Hint (constructs to consider)** → bisect, bisect_left, bisect_right

# %%
# ⬇️ Write your solution for Problem 5 below

import bisect
from typing import Generator

WDAYS = 5
evl = []
g: Generator = generate_events(300)
for ev in g:
    bisect.insort_right(evl, ev, key=lambda x: x.get("ts"))


last_ev = evl[-1]
first_event = datetime.fromisoformat(last_ev.get("ts"))
oldest_event = first_event - timedelta(days=5)

idx = bisect.bisect_right(evl, first_event.isoformat(), key=lambda e: e.get("ts"))
idx

# TODO
# Out:
# 300

# %%
len(evl) - 281
# Out:
# 19

# %%
datetime.fromisoformat(evl[282]["ts"]) < first_event <  datetime.fromisoformat(evl[283]["ts"])
# Out:
# False

# %%
oldest_event
# Out:
# datetime.datetime(2025, 6, 6, 1, 22, 1, 606680)

# %%
first_event
# Out:
# datetime.datetime(2025, 6, 11, 1, 22, 1, 606680)

# %%
evl[280:282]
# Out:
# [{'id': 155,
#   'ts': '2025-06-05T07:37:50.606680',
#   'user': 'user7',
#   'type': 'CLICK',
#   'payload': {'value': 235}},
#  {'id': 115,
#   'ts': '2025-06-05T15:06:14.606680',
#   'user': 'user43',
#   'type': 'LOGOUT',
#   'payload': {'value': 102}}]

# %% [markdown]
# ---
#
# ### Problem 6 – Daily Cumulative Event Counts
#
# **Task**
# Daily Cumulative Event Counts.
#
# **Hint (constructs to consider)** → itertools.groupby, itertools.accumulate

# %%
from itertools import groupby
# ⬇️ Write your solution for Problem 6 below

from datetime import datetime

events = [(datetime.fromisoformat(ev['ts']).date(), ev) for ev in generate_events(3000)]

events.sort(key = lambda x: x[0])

for day, group in groupby(events, key= lambda x: x[0]):
    print(f"{day}: {(list(group))[:3]}")
# Out:
# 2025-03-04: [(datetime.date(2025, 3, 4), {'id': 197, 'ts': '2025-03-04T11:45:14.472049', 'user': 'user45', 'type': 'CLICK', 'payload': {'value': 581}}), (datetime.date(2025, 3, 4), {'id': 703, 'ts': '2025-03-04T22:14:44.472049', 'user': 'user33', 'type': 'LOGIN', 'payload': {'value': 637}}), (datetime.date(2025, 3, 4), {'id': 950, 'ts': '2025-03-04T14:37:16.472049', 'user': 'user45', 'type': 'VIEW', 'payload': {'value': 683}})]
# 2025-03-05: [(datetime.date(2025, 3, 5), {'id': 96, 'ts': '2025-03-05T03:06:44.472049', 'user': 'user14', 'type': 'LOGOUT', 'payload': {'value': 442}}), (datetime.date(2025, 3, 5), {'id': 109, 'ts': '2025-03-05T01:11:32.472049', 'user': 'user23', 'type': 'PURCHASE', 'payload': {'value': 601}}), (datetime.date(2025, 3, 5), {'id': 133, 'ts': '2025-03-05T04:59:59.472049', 'user': 'user39', 'type': 'LOGOUT', 'payload': {'value': 527}})]
# 2025-03-06: [(datetime.date(2025, 3, 6), {'id': 4, 'ts': '2025-03-06T08:13:05.472049', 'user': 'user27', 'type': 'VIEW', 'payload': {'value': 193}}), (datetime.date(2025, 3, 6), {'id': 154, 'ts': '2025-03-06T23:49:37.472049', 'user': 'user33', 'type': 'LOGOUT', 'payload': {'value': 913}}), (datetime.date(2025, 3, 6), {'id': 328, 'ts': '2025-03-06T01:31:08.472049', 'user': 'user40', 'type': 'LOGOUT', 'payload': {'value': 218}})]
# 2025-03-07: [(datetime.date(2025, 3, 7), {'id': 65, 'ts': '2025-03-07T17:00:57.472049', 'user': 'user24', 'type': 'CLICK', 'payload': {'value': 953}}), (datetime.date(2025, 3, 7), {'id': 142, 'ts': '2025-03-07T08:56:29.472049', 'user': 'user44', 'type': 'VIEW', 'payload': {'value': 174}}), (datetime.date(2025, 3, 7), {'id': 218, 'ts': '2025-03-07T17:05:41.472049', 'user': 'user49', 'type': 'VIEW', 'payload': {'value': 725}})]
# 2025-03-08: [(datetime.date(2025, 3, 8), {'id': 26, 'ts': '2025-03-08T17:03:44.472049', 'user': 'user10', 'type': 'VIEW', 'payload': {'value': 81}}), (datetime.date(2025, 3, 8), {'id': 41, 'ts': '2025-03-08T01:47:55.472049', 'user': 'user4', 'type': 'PURCHASE', 'payload': {'value': 960}}), (datetime.date(2025, 3, 8), {'id': 166, 'ts': '2025-03-08T12:35:02.472049', 'user': 'user49', 'type': 'CLICK', 'payload': {'value': 150}})]
# 2025-03-09: [(datetime.date(2025, 3, 9), {'id': 221, 'ts': '2025-03-09T15:05:48.472049', 'user': 'user42', 'type': 'PURCHASE', 'payload': {'value': 285}}), (datetime.date(2025, 3, 9), {'id': 227, 'ts': '2025-03-09T07:37:57.472049', 'user': 'user35', 'type': 'PURCHASE', 'payload': {'value': 337}}), (datetime.date(2025, 3, 9), {'id': 603, 'ts': '2025-03-09T23:17:37.472049', 'user': 'user50', 'type': 'LOGIN', 'payload': {'value': 565}})]
# 2025-03-10: [(datetime.date(2025, 3, 10), {'id': 147, 'ts': '2025-03-10T23:06:20.472049', 'user': 'user15', 'type': 'VIEW', 'payload': {'value': 861}}), (datetime.date(2025, 3, 10), {'id': 150, 'ts': '2025-03-10T14:32:12.472049', 'user': 'user1', 'type': 'VIEW', 'payload': {'value': 493}}), (datetime.date(2025, 3, 10), {'id': 445, 'ts': '2025-03-10T01:18:09.472049', 'user': 'user3', 'type': 'LOGIN', 'payload': {'value': 55}})]
# 2025-03-11: [(datetime.date(2025, 3, 11), {'id': 383, 'ts': '2025-03-11T12:25:43.472049', 'user': 'user26', 'type': 'LOGOUT', 'payload': {'value': 122}}), (datetime.date(2025, 3, 11), {'id': 570, 'ts': '2025-03-11T14:36:25.472049', 'user': 'user12', 'type': 'VIEW', 'payload': {'value': 547}}), (datetime.date(2025, 3, 11), {'id': 577, 'ts': '2025-03-11T08:34:12.472049', 'user': 'user37', 'type': 'LOGOUT', 'payload': {'value': 362}})]
# 2025-03-12: [(datetime.date(2025, 3, 12), {'id': 208, 'ts': '2025-03-12T07:02:48.472049', 'user': 'user42', 'type': 'VIEW', 'payload': {'value': 277}}), (datetime.date(2025, 3, 12), {'id': 239, 'ts': '2025-03-12T02:27:21.472049', 'user': 'user41', 'type': 'VIEW', 'payload': {'value': 24}}), (datetime.date(2025, 3, 12), {'id': 273, 'ts': '2025-03-12T15:31:25.472049', 'user': 'user44', 'type': 'LOGOUT', 'payload': {'value': 432}})]
# 2025-03-13: [(datetime.date(2025, 3, 13), {'id': 13, 'ts': '2025-03-13T12:00:14.472049', 'user': 'user40', 'type': 'LOGIN', 'payload': {'value': 107}}), (datetime.date(2025, 3, 13), {'id': 131, 'ts': '2025-03-13T12:14:58.472049', 'user': 'user33', 'type': 'VIEW', 'payload': {'value': 22}}), (datetime.date(2025, 3, 13), {'id': 159, 'ts': '2025-03-13T04:38:01.472049', 'user': 'user2', 'type': 'LOGOUT', 'payload': {'value': 598}})]
# 2025-03-14: [(datetime.date(2025, 3, 14), {'id': 156, 'ts': '2025-03-14T01:50:35.472049', 'user': 'user35', 'type': 'LOGIN', 'payload': {'value': 120}}), (datetime.date(2025, 3, 14), {'id': 401, 'ts': '2025-03-14T19:00:27.472049', 'user': 'user23', 'type': 'LOGOUT', 'payload': {'value': 251}}), (datetime.date(2025, 3, 14), {'id': 554, 'ts': '2025-03-14T07:50:10.472049', 'user': 'user17', 'type': 'LOGOUT', 'payload': {'value': 930}})]
# 2025-03-15: [(datetime.date(2025, 3, 15), {'id': 198, 'ts': '2025-03-15T15:37:51.472049', 'user': 'user8', 'type': 'CLICK', 'payload': {'value': 5}}), (datetime.date(2025, 3, 15), {'id': 238, 'ts': '2025-03-15T19:30:41.472049', 'user': 'user6', 'type': 'LOGOUT', 'payload': {'value': 476}}), (datetime.date(2025, 3, 15), {'id': 271, 'ts': '2025-03-15T17:00:43.472049', 'user': 'user31', 'type': 'PURCHASE', 'payload': {'value': 564}})]
# 2025-03-16: [(datetime.date(2025, 3, 16), {'id': 20, 'ts': '2025-03-16T14:36:37.472049', 'user': 'user44', 'type': 'LOGOUT', 'payload': {'value': 79}}), (datetime.date(2025, 3, 16), {'id': 52, 'ts': '2025-03-16T23:01:02.472049', 'user': 'user44', 'type': 'LOGIN', 'payload': {'value': 222}}), (datetime.date(2025, 3, 16), {'id': 163, 'ts': '2025-03-16T11:54:37.472049', 'user': 'user16', 'type': 'PURCHASE', 'payload': {'value': 303}})]
# 2025-03-17: [(datetime.date(2025, 3, 17), {'id': 3, 'ts': '2025-03-17T15:49:45.472049', 'user': 'user45', 'type': 'LOGOUT', 'payload': {'value': 803}}), (datetime.date(2025, 3, 17), {'id': 212, 'ts': '2025-03-17T20:39:24.472049', 'user': 'user3', 'type': 'CLICK', 'payload': {'value': 427}}), (datetime.date(2025, 3, 17), {'id': 326, 'ts': '2025-03-17T01:51:52.472049', 'user': 'user5', 'type': 'CLICK', 'payload': {'value': 325}})]
# 2025-03-18: [(datetime.date(2025, 3, 18), {'id': 36, 'ts': '2025-03-18T22:23:45.472049', 'user': 'user27', 'type': 'LOGIN', 'payload': {'value': 764}}), (datetime.date(2025, 3, 18), {'id': 310, 'ts': '2025-03-18T10:14:43.472049', 'user': 'user38', 'type': 'LOGIN', 'payload': {'value': 273}}), (datetime.date(2025, 3, 18), {'id': 349, 'ts': '2025-03-18T12:44:48.472049', 'user': 'user11', 'type': 'LOGIN', 'payload': {'value': 351}})]
# 2025-03-19: [(datetime.date(2025, 3, 19), {'id': 25, 'ts': '2025-03-19T14:46:48.472049', 'user': 'user34', 'type': 'LOGOUT', 'payload': {'value': 564}}), (datetime.date(2025, 3, 19), {'id': 55, 'ts': '2025-03-19T02:35:59.472049', 'user': 'user34', 'type': 'LOGIN', 'payload': {'value': 41}}), (datetime.date(2025, 3, 19), {'id': 102, 'ts': '2025-03-19T15:11:14.472049', 'user': 'user11', 'type': 'LOGIN', 'payload': {'value': 258}})]
# 2025-03-20: [(datetime.date(2025, 3, 20), {'id': 5, 'ts': '2025-03-20T12:12:06.472049', 'user': 'user23', 'type': 'LOGIN', 'payload': {'value': 231}}), (datetime.date(2025, 3, 20), {'id': 80, 'ts': '2025-03-20T22:48:03.472049', 'user': 'user7', 'type': 'PURCHASE', 'payload': {'value': 145}}), (datetime.date(2025, 3, 20), {'id': 177, 'ts': '2025-03-20T13:51:20.472049', 'user': 'user48', 'type': 'CLICK', 'payload': {'value': 238}})]
# 2025-03-21: [(datetime.date(2025, 3, 21), {'id': 30, 'ts': '2025-03-21T19:46:37.472049', 'user': 'user31', 'type': 'VIEW', 'payload': {'value': 303}}), (datetime.date(2025, 3, 21), {'id': 31, 'ts': '2025-03-21T19:50:58.472049', 'user': 'user31', 'type': 'LOGIN', 'payload': {'value': 934}}), (datetime.date(2025, 3, 21), {'id': 32, 'ts': '2025-03-21T10:58:01.472049', 'user': 'user18', 'type': 'PURCHASE', 'payload': {'value': 856}})]
# 2025-03-22: [(datetime.date(2025, 3, 22), {'id': 66, 'ts': '2025-03-22T19:55:53.472049', 'user': 'user25', 'type': 'VIEW', 'payload': {'value': 245}}), (datetime.date(2025, 3, 22), {'id': 214, 'ts': '2025-03-22T12:06:34.472049', 'user': 'user39', 'type': 'LOGOUT', 'payload': {'value': 719}}), (datetime.date(2025, 3, 22), {'id': 247, 'ts': '2025-03-22T21:21:13.472049', 'user': 'user35', 'type': 'CLICK', 'payload': {'value': 461}})]
# 2025-03-23: [(datetime.date(2025, 3, 23), {'id': 58, 'ts': '2025-03-23T11:07:59.472049', 'user': 'user50', 'type': 'VIEW', 'payload': {'value': 149}}), (datetime.date(2025, 3, 23), {'id': 64, 'ts': '2025-03-23T09:39:14.472049', 'user': 'user37', 'type': 'VIEW', 'payload': {'value': 663}}), (datetime.date(2025, 3, 23), {'id': 301, 'ts': '2025-03-23T00:37:11.472049', 'user': 'user28', 'type': 'LOGOUT', 'payload': {'value': 731}})]
# 2025-03-24: [(datetime.date(2025, 3, 24), {'id': 103, 'ts': '2025-03-24T13:42:06.472049', 'user': 'user19', 'type': 'LOGIN', 'payload': {'value': 140}}), (datetime.date(2025, 3, 24), {'id': 151, 'ts': '2025-03-24T14:06:35.472049', 'user': 'user32', 'type': 'CLICK', 'payload': {'value': 806}}), (datetime.date(2025, 3, 24), {'id': 224, 'ts': '2025-03-24T16:10:11.472049', 'user': 'user29', 'type': 'LOGOUT', 'payload': {'value': 385}})]
# 2025-03-25: [(datetime.date(2025, 3, 25), {'id': 22, 'ts': '2025-03-25T23:07:38.472049', 'user': 'user1', 'type': 'LOGIN', 'payload': {'value': 805}}), (datetime.date(2025, 3, 25), {'id': 72, 'ts': '2025-03-25T08:52:24.472049', 'user': 'user9', 'type': 'LOGOUT', 'payload': {'value': 788}}), (datetime.date(2025, 3, 25), {'id': 185, 'ts': '2025-03-25T18:33:48.472049', 'user': 'user43', 'type': 'LOGIN', 'payload': {'value': 683}})]
# 2025-03-26: [(datetime.date(2025, 3, 26), {'id': 136, 'ts': '2025-03-26T16:55:13.472049', 'user': 'user1', 'type': 'LOGOUT', 'payload': {'value': 281}}), (datetime.date(2025, 3, 26), {'id': 180, 'ts': '2025-03-26T14:03:46.472049', 'user': 'user41', 'type': 'PURCHASE', 'payload': {'value': 184}}), (datetime.date(2025, 3, 26), {'id': 206, 'ts': '2025-03-26T06:32:04.472049', 'user': 'user23', 'type': 'LOGIN', 'payload': {'value': 894}})]
# 2025-03-27: [(datetime.date(2025, 3, 27), {'id': 119, 'ts': '2025-03-27T20:16:13.472049', 'user': 'user48', 'type': 'LOGIN', 'payload': {'value': 685}}), (datetime.date(2025, 3, 27), {'id': 331, 'ts': '2025-03-27T00:20:21.472049', 'user': 'user47', 'type': 'CLICK', 'payload': {'value': 511}}), (datetime.date(2025, 3, 27), {'id': 353, 'ts': '2025-03-27T18:40:17.472049', 'user': 'user36', 'type': 'VIEW', 'payload': {'value': 149}})]
# 2025-03-28: [(datetime.date(2025, 3, 28), {'id': 9, 'ts': '2025-03-28T10:59:30.472049', 'user': 'user8', 'type': 'PURCHASE', 'payload': {'value': 773}}), (datetime.date(2025, 3, 28), {'id': 124, 'ts': '2025-03-28T15:01:46.472049', 'user': 'user17', 'type': 'LOGOUT', 'payload': {'value': 887}}), (datetime.date(2025, 3, 28), {'id': 236, 'ts': '2025-03-28T11:45:49.472049', 'user': 'user1', 'type': 'PURCHASE', 'payload': {'value': 643}})]
# 2025-03-29: [(datetime.date(2025, 3, 29), {'id': 93, 'ts': '2025-03-29T08:08:56.472049', 'user': 'user19', 'type': 'LOGIN', 'payload': {'value': 396}}), (datetime.date(2025, 3, 29), {'id': 113, 'ts': '2025-03-29T06:20:54.472049', 'user': 'user18', 'type': 'LOGIN', 'payload': {'value': 856}}), (datetime.date(2025, 3, 29), {'id': 127, 'ts': '2025-03-29T11:33:06.472049', 'user': 'user28', 'type': 'CLICK', 'payload': {'value': 357}})]
# 2025-03-30: [(datetime.date(2025, 3, 30), {'id': 130, 'ts': '2025-03-30T07:05:42.472049', 'user': 'user47', 'type': 'CLICK', 'payload': {'value': 881}}), (datetime.date(2025, 3, 30), {'id': 144, 'ts': '2025-03-30T19:35:53.472049', 'user': 'user24', 'type': 'PURCHASE', 'payload': {'value': 586}}), (datetime.date(2025, 3, 30), {'id': 170, 'ts': '2025-03-30T15:28:59.472049', 'user': 'user37', 'type': 'PURCHASE', 'payload': {'value': 554}})]
# 2025-05-01: [(datetime.date(2025, 5, 1), {'id': 60, 'ts': '2025-05-01T11:24:01.472049', 'user': 'user40', 'type': 'LOGOUT', 'payload': {'value': 107}}), (datetime.date(2025, 5, 1), {'id': 110, 'ts': '2025-05-01T12:53:18.472049', 'user': 'user43', 'type': 'CLICK', 'payload': {'value': 396}}), (datetime.date(2025, 5, 1), {'id': 123, 'ts': '2025-05-01T18:30:54.472049', 'user': 'user13', 'type': 'PURCHASE', 'payload': {'value': 455}})]
# 2025-05-02: [(datetime.date(2025, 5, 2), {'id': 6, 'ts': '2025-05-02T21:34:48.472049', 'user': 'user19', 'type': 'LOGOUT', 'payload': {'value': 81}}), (datetime.date(2025, 5, 2), {'id': 175, 'ts': '2025-05-02T00:24:39.472049', 'user': 'user29', 'type': 'PURCHASE', 'payload': {'value': 53}}), (datetime.date(2025, 5, 2), {'id': 188, 'ts': '2025-05-02T09:10:18.472049', 'user': 'user10', 'type': 'CLICK', 'payload': {'value': 116}})]
# 2025-05-03: [(datetime.date(2025, 5, 3), {'id': 40, 'ts': '2025-05-03T03:01:32.472049', 'user': 'user33', 'type': 'PURCHASE', 'payload': {'value': 341}}), (datetime.date(2025, 5, 3), {'id': 87, 'ts': '2025-05-03T18:42:46.472049', 'user': 'user23', 'type': 'CLICK', 'payload': {'value': 790}}), (datetime.date(2025, 5, 3), {'id': 288, 'ts': '2025-05-03T08:19:51.472049', 'user': 'user2', 'type': 'PURCHASE', 'payload': {'value': 97}})]
# 2025-05-04: [(datetime.date(2025, 5, 4), {'id': 11, 'ts': '2025-05-04T18:28:51.472049', 'user': 'user38', 'type': 'PURCHASE', 'payload': {'value': 246}}), (datetime.date(2025, 5, 4), {'id': 167, 'ts': '2025-05-04T17:58:28.472049', 'user': 'user39', 'type': 'LOGOUT', 'payload': {'value': 437}}), (datetime.date(2025, 5, 4), {'id': 532, 'ts': '2025-05-04T08:32:03.472049', 'user': 'user41', 'type': 'LOGIN', 'payload': {'value': 208}})]
# 2025-05-05: [(datetime.date(2025, 5, 5), {'id': 111, 'ts': '2025-05-05T20:18:42.472049', 'user': 'user12', 'type': 'LOGIN', 'payload': {'value': 223}}), (datetime.date(2025, 5, 5), {'id': 183, 'ts': '2025-05-05T14:41:36.472049', 'user': 'user35', 'type': 'LOGOUT', 'payload': {'value': 662}}), (datetime.date(2025, 5, 5), {'id': 267, 'ts': '2025-05-05T15:46:20.472049', 'user': 'user31', 'type': 'LOGOUT', 'payload': {'value': 608}})]
# 2025-05-06: [(datetime.date(2025, 5, 6), {'id': 82, 'ts': '2025-05-06T17:25:48.472049', 'user': 'user37', 'type': 'CLICK', 'payload': {'value': 255}}), (datetime.date(2025, 5, 6), {'id': 129, 'ts': '2025-05-06T00:53:21.472049', 'user': 'user49', 'type': 'PURCHASE', 'payload': {'value': 563}}), (datetime.date(2025, 5, 6), {'id': 174, 'ts': '2025-05-06T06:57:06.472049', 'user': 'user32', 'type': 'CLICK', 'payload': {'value': 807}})]
# 2025-05-07: [(datetime.date(2025, 5, 7), {'id': 153, 'ts': '2025-05-07T00:22:56.472049', 'user': 'user10', 'type': 'LOGIN', 'payload': {'value': 391}}), (datetime.date(2025, 5, 7), {'id': 232, 'ts': '2025-05-07T21:21:53.472049', 'user': 'user17', 'type': 'LOGOUT', 'payload': {'value': 988}}), (datetime.date(2025, 5, 7), {'id': 335, 'ts': '2025-05-07T18:00:25.472049', 'user': 'user12', 'type': 'CLICK', 'payload': {'value': 319}})]
# 2025-05-08: [(datetime.date(2025, 5, 8), {'id': 23, 'ts': '2025-05-08T03:38:28.472049', 'user': 'user46', 'type': 'LOGOUT', 'payload': {'value': 587}}), (datetime.date(2025, 5, 8), {'id': 172, 'ts': '2025-05-08T11:05:27.472049', 'user': 'user20', 'type': 'VIEW', 'payload': {'value': 829}}), (datetime.date(2025, 5, 8), {'id': 192, 'ts': '2025-05-08T13:50:59.472049', 'user': 'user8', 'type': 'PURCHASE', 'payload': {'value': 211}})]
# 2025-05-09: [(datetime.date(2025, 5, 9), {'id': 50, 'ts': '2025-05-09T19:33:13.472049', 'user': 'user10', 'type': 'LOGIN', 'payload': {'value': 971}}), (datetime.date(2025, 5, 9), {'id': 173, 'ts': '2025-05-09T08:19:14.472049', 'user': 'user44', 'type': 'LOGOUT', 'payload': {'value': 946}}), (datetime.date(2025, 5, 9), {'id': 182, 'ts': '2025-05-09T01:59:50.472049', 'user': 'user49', 'type': 'CLICK', 'payload': {'value': 382}})]
# 2025-05-10: [(datetime.date(2025, 5, 10), {'id': 0, 'ts': '2025-05-10T15:46:52.472049', 'user': 'user22', 'type': 'PURCHASE', 'payload': {'value': 408}}), (datetime.date(2025, 5, 10), {'id': 33, 'ts': '2025-05-10T10:48:51.472049', 'user': 'user24', 'type': 'LOGIN', 'payload': {'value': 336}}), (datetime.date(2025, 5, 10), {'id': 53, 'ts': '2025-05-10T13:50:23.472049', 'user': 'user2', 'type': 'LOGOUT', 'payload': {'value': 18}})]
# 2025-05-11: [(datetime.date(2025, 5, 11), {'id': 254, 'ts': '2025-05-11T08:18:25.472049', 'user': 'user35', 'type': 'LOGIN', 'payload': {'value': 817}}), (datetime.date(2025, 5, 11), {'id': 347, 'ts': '2025-05-11T19:42:10.472049', 'user': 'user39', 'type': 'VIEW', 'payload': {'value': 568}}), (datetime.date(2025, 5, 11), {'id': 414, 'ts': '2025-05-11T08:11:35.472049', 'user': 'user38', 'type': 'CLICK', 'payload': {'value': 749}})]
# 2025-05-12: [(datetime.date(2025, 5, 12), {'id': 157, 'ts': '2025-05-12T21:58:07.472049', 'user': 'user6', 'type': 'VIEW', 'payload': {'value': 144}}), (datetime.date(2025, 5, 12), {'id': 324, 'ts': '2025-05-12T10:05:15.472049', 'user': 'user6', 'type': 'LOGOUT', 'payload': {'value': 638}}), (datetime.date(2025, 5, 12), {'id': 339, 'ts': '2025-05-12T22:46:35.472049', 'user': 'user14', 'type': 'PURCHASE', 'payload': {'value': 703}})]
# 2025-05-13: [(datetime.date(2025, 5, 13), {'id': 70, 'ts': '2025-05-13T12:42:32.472049', 'user': 'user32', 'type': 'CLICK', 'payload': {'value': 114}}), (datetime.date(2025, 5, 13), {'id': 391, 'ts': '2025-05-13T18:44:20.472049', 'user': 'user27', 'type': 'LOGIN', 'payload': {'value': 86}}), (datetime.date(2025, 5, 13), {'id': 452, 'ts': '2025-05-13T00:55:59.472049', 'user': 'user17', 'type': 'VIEW', 'payload': {'value': 904}})]
# 2025-05-14: [(datetime.date(2025, 5, 14), {'id': 178, 'ts': '2025-05-14T12:55:47.472049', 'user': 'user13', 'type': 'VIEW', 'payload': {'value': 412}}), (datetime.date(2025, 5, 14), {'id': 209, 'ts': '2025-05-14T16:06:19.472049', 'user': 'user39', 'type': 'LOGIN', 'payload': {'value': 547}}), (datetime.date(2025, 5, 14), {'id': 231, 'ts': '2025-05-14T02:45:06.472049', 'user': 'user47', 'type': 'PURCHASE', 'payload': {'value': 395}})]
# 2025-05-15: [(datetime.date(2025, 5, 15), {'id': 84, 'ts': '2025-05-15T20:47:37.472049', 'user': 'user16', 'type': 'LOGIN', 'payload': {'value': 443}}), (datetime.date(2025, 5, 15), {'id': 116, 'ts': '2025-05-15T00:46:10.472049', 'user': 'user21', 'type': 'CLICK', 'payload': {'value': 772}}), (datetime.date(2025, 5, 15), {'id': 155, 'ts': '2025-05-15T01:23:36.472049', 'user': 'user37', 'type': 'VIEW', 'payload': {'value': 979}})]
# 2025-05-16: [(datetime.date(2025, 5, 16), {'id': 56, 'ts': '2025-05-16T21:22:55.472049', 'user': 'user14', 'type': 'LOGOUT', 'payload': {'value': 158}}), (datetime.date(2025, 5, 16), {'id': 95, 'ts': '2025-05-16T06:21:47.472049', 'user': 'user9', 'type': 'LOGOUT', 'payload': {'value': 500}}), (datetime.date(2025, 5, 16), {'id': 187, 'ts': '2025-05-16T06:18:31.472049', 'user': 'user8', 'type': 'CLICK', 'payload': {'value': 352}})]
# 2025-05-17: [(datetime.date(2025, 5, 17), {'id': 299, 'ts': '2025-05-17T22:27:29.472049', 'user': 'user13', 'type': 'LOGOUT', 'payload': {'value': 215}}), (datetime.date(2025, 5, 17), {'id': 641, 'ts': '2025-05-17T08:25:03.472049', 'user': 'user35', 'type': 'VIEW', 'payload': {'value': 266}}), (datetime.date(2025, 5, 17), {'id': 700, 'ts': '2025-05-17T07:31:45.472049', 'user': 'user32', 'type': 'LOGOUT', 'payload': {'value': 630}})]
# 2025-05-18: [(datetime.date(2025, 5, 18), {'id': 615, 'ts': '2025-05-18T14:48:29.472049', 'user': 'user38', 'type': 'CLICK', 'payload': {'value': 936}}), (datetime.date(2025, 5, 18), {'id': 680, 'ts': '2025-05-18T20:42:47.472049', 'user': 'user11', 'type': 'VIEW', 'payload': {'value': 727}}), (datetime.date(2025, 5, 18), {'id': 921, 'ts': '2025-05-18T18:52:47.472049', 'user': 'user40', 'type': 'LOGOUT', 'payload': {'value': 70}})]
# 2025-05-19: [(datetime.date(2025, 5, 19), {'id': 46, 'ts': '2025-05-19T15:38:03.472049', 'user': 'user42', 'type': 'PURCHASE', 'payload': {'value': 629}}), (datetime.date(2025, 5, 19), {'id': 68, 'ts': '2025-05-19T07:14:45.472049', 'user': 'user9', 'type': 'LOGIN', 'payload': {'value': 597}}), (datetime.date(2025, 5, 19), {'id': 256, 'ts': '2025-05-19T06:50:06.472049', 'user': 'user5', 'type': 'LOGIN', 'payload': {'value': 588}})]
# 2025-05-20: [(datetime.date(2025, 5, 20), {'id': 19, 'ts': '2025-05-20T16:20:11.472049', 'user': 'user28', 'type': 'PURCHASE', 'payload': {'value': 64}}), (datetime.date(2025, 5, 20), {'id': 28, 'ts': '2025-05-20T13:48:10.472049', 'user': 'user3', 'type': 'LOGIN', 'payload': {'value': 36}}), (datetime.date(2025, 5, 20), {'id': 45, 'ts': '2025-05-20T13:55:56.472049', 'user': 'user17', 'type': 'PURCHASE', 'payload': {'value': 21}})]
# 2025-05-21: [(datetime.date(2025, 5, 21), {'id': 264, 'ts': '2025-05-21T11:49:53.472049', 'user': 'user32', 'type': 'LOGIN', 'payload': {'value': 719}}), (datetime.date(2025, 5, 21), {'id': 322, 'ts': '2025-05-21T12:18:14.472049', 'user': 'user25', 'type': 'LOGIN', 'payload': {'value': 234}}), (datetime.date(2025, 5, 21), {'id': 337, 'ts': '2025-05-21T03:22:54.472049', 'user': 'user46', 'type': 'LOGIN', 'payload': {'value': 92}})]
# 2025-05-22: [(datetime.date(2025, 5, 22), {'id': 199, 'ts': '2025-05-22T22:58:43.472049', 'user': 'user16', 'type': 'LOGOUT', 'payload': {'value': 169}}), (datetime.date(2025, 5, 22), {'id': 387, 'ts': '2025-05-22T09:33:47.472049', 'user': 'user11', 'type': 'CLICK', 'payload': {'value': 481}}), (datetime.date(2025, 5, 22), {'id': 413, 'ts': '2025-05-22T21:20:19.472049', 'user': 'user12', 'type': 'LOGIN', 'payload': {'value': 682}})]
# 2025-05-23: [(datetime.date(2025, 5, 23), {'id': 235, 'ts': '2025-05-23T01:08:45.472049', 'user': 'user34', 'type': 'LOGOUT', 'payload': {'value': 527}}), (datetime.date(2025, 5, 23), {'id': 252, 'ts': '2025-05-23T05:39:50.472049', 'user': 'user21', 'type': 'PURCHASE', 'payload': {'value': 95}}), (datetime.date(2025, 5, 23), {'id': 292, 'ts': '2025-05-23T21:37:31.472049', 'user': 'user12', 'type': 'LOGOUT', 'payload': {'value': 903}})]
# 2025-05-24: [(datetime.date(2025, 5, 24), {'id': 14, 'ts': '2025-05-24T10:49:19.472049', 'user': 'user10', 'type': 'PURCHASE', 'payload': {'value': 988}}), (datetime.date(2025, 5, 24), {'id': 246, 'ts': '2025-05-24T15:49:37.472049', 'user': 'user7', 'type': 'LOGIN', 'payload': {'value': 872}}), (datetime.date(2025, 5, 24), {'id': 276, 'ts': '2025-05-24T15:00:42.472049', 'user': 'user27', 'type': 'VIEW', 'payload': {'value': 212}})]
# 2025-05-25: [(datetime.date(2025, 5, 25), {'id': 752, 'ts': '2025-05-25T07:58:44.472049', 'user': 'user5', 'type': 'CLICK', 'payload': {'value': 555}}), (datetime.date(2025, 5, 25), {'id': 1124, 'ts': '2025-05-25T10:53:54.472049', 'user': 'user33', 'type': 'LOGIN', 'payload': {'value': 568}}), (datetime.date(2025, 5, 25), {'id': 1166, 'ts': '2025-05-25T10:02:47.472049', 'user': 'user48', 'type': 'LOGIN', 'payload': {'value': 639}})]
# 2025-05-26: [(datetime.date(2025, 5, 26), {'id': 47, 'ts': '2025-05-26T06:52:31.472049', 'user': 'user41', 'type': 'PURCHASE', 'payload': {'value': 498}}), (datetime.date(2025, 5, 26), {'id': 91, 'ts': '2025-05-26T16:41:20.472049', 'user': 'user36', 'type': 'VIEW', 'payload': {'value': 545}}), (datetime.date(2025, 5, 26), {'id': 122, 'ts': '2025-05-26T15:15:03.472049', 'user': 'user12', 'type': 'VIEW', 'payload': {'value': 27}})]
# 2025-05-27: [(datetime.date(2025, 5, 27), {'id': 100, 'ts': '2025-05-27T09:52:30.472049', 'user': 'user13', 'type': 'PURCHASE', 'payload': {'value': 892}}), (datetime.date(2025, 5, 27), {'id': 184, 'ts': '2025-05-27T14:58:13.472049', 'user': 'user27', 'type': 'VIEW', 'payload': {'value': 838}}), (datetime.date(2025, 5, 27), {'id': 345, 'ts': '2025-05-27T23:27:47.472049', 'user': 'user23', 'type': 'PURCHASE', 'payload': {'value': 485}})]
# 2025-05-28: [(datetime.date(2025, 5, 28), {'id': 79, 'ts': '2025-05-28T04:07:33.472049', 'user': 'user1', 'type': 'PURCHASE', 'payload': {'value': 636}}), (datetime.date(2025, 5, 28), {'id': 255, 'ts': '2025-05-28T21:30:21.472049', 'user': 'user37', 'type': 'LOGIN', 'payload': {'value': 90}}), (datetime.date(2025, 5, 28), {'id': 407, 'ts': '2025-05-28T13:14:16.472049', 'user': 'user3', 'type': 'PURCHASE', 'payload': {'value': 892}})]
# 2025-05-29: [(datetime.date(2025, 5, 29), {'id': 162, 'ts': '2025-05-29T04:57:00.472049', 'user': 'user8', 'type': 'LOGIN', 'payload': {'value': 597}}), (datetime.date(2025, 5, 29), {'id': 318, 'ts': '2025-05-29T15:46:52.472049', 'user': 'user22', 'type': 'PURCHASE', 'payload': {'value': 353}}), (datetime.date(2025, 5, 29), {'id': 547, 'ts': '2025-05-29T17:22:54.472049', 'user': 'user6', 'type': 'CLICK', 'payload': {'value': 521}})]
# 2025-05-30: [(datetime.date(2025, 5, 30), {'id': 78, 'ts': '2025-05-30T18:43:30.472049', 'user': 'user26', 'type': 'CLICK', 'payload': {'value': 699}}), (datetime.date(2025, 5, 30), {'id': 90, 'ts': '2025-05-30T00:50:32.472049', 'user': 'user43', 'type': 'PURCHASE', 'payload': {'value': 93}}), (datetime.date(2025, 5, 30), {'id': 117, 'ts': '2025-05-30T16:01:45.472049', 'user': 'user31', 'type': 'LOGIN', 'payload': {'value': 945}})]
# 2025-05-31: [(datetime.date(2025, 5, 31), {'id': 15, 'ts': '2025-05-31T18:04:07.472049', 'user': 'user12', 'type': 'LOGIN', 'payload': {'value': 12}}), (datetime.date(2025, 5, 31), {'id': 59, 'ts': '2025-05-31T20:54:09.472049', 'user': 'user6', 'type': 'CLICK', 'payload': {'value': 36}}), (datetime.date(2025, 5, 31), {'id': 325, 'ts': '2025-05-31T01:46:58.472049', 'user': 'user41', 'type': 'VIEW', 'payload': {'value': 940}})]
# 2025-06-01: [(datetime.date(2025, 6, 1), {'id': 86, 'ts': '2025-06-01T18:32:41.472049', 'user': 'user47', 'type': 'VIEW', 'payload': {'value': 736}}), (datetime.date(2025, 6, 1), {'id': 160, 'ts': '2025-06-01T01:21:03.472049', 'user': 'user45', 'type': 'LOGIN', 'payload': {'value': 592}}), (datetime.date(2025, 6, 1), {'id': 262, 'ts': '2025-06-01T01:30:59.472049', 'user': 'user50', 'type': 'VIEW', 'payload': {'value': 814}})]
# 2025-06-02: [(datetime.date(2025, 6, 2), {'id': 241, 'ts': '2025-06-02T12:23:34.472049', 'user': 'user48', 'type': 'PURCHASE', 'payload': {'value': 132}}), (datetime.date(2025, 6, 2), {'id': 432, 'ts': '2025-06-02T04:41:05.472049', 'user': 'user11', 'type': 'VIEW', 'payload': {'value': 574}}), (datetime.date(2025, 6, 2), {'id': 502, 'ts': '2025-06-02T01:05:42.472049', 'user': 'user4', 'type': 'VIEW', 'payload': {'value': 396}})]
# 2025-06-03: [(datetime.date(2025, 6, 3), {'id': 165, 'ts': '2025-06-03T21:00:09.472049', 'user': 'user9', 'type': 'LOGIN', 'payload': {'value': 629}}), (datetime.date(2025, 6, 3), {'id': 298, 'ts': '2025-06-03T00:25:05.472049', 'user': 'user49', 'type': 'CLICK', 'payload': {'value': 388}}), (datetime.date(2025, 6, 3), {'id': 851, 'ts': '2025-06-03T22:22:29.472049', 'user': 'user23', 'type': 'VIEW', 'payload': {'value': 83}})]
# 2025-06-04: [(datetime.date(2025, 6, 4), {'id': 63, 'ts': '2025-06-04T00:48:06.472049', 'user': 'user46', 'type': 'CLICK', 'payload': {'value': 751}}), (datetime.date(2025, 6, 4), {'id': 132, 'ts': '2025-06-04T09:34:42.472049', 'user': 'user42', 'type': 'LOGOUT', 'payload': {'value': 875}}), (datetime.date(2025, 6, 4), {'id': 312, 'ts': '2025-06-04T07:20:01.472049', 'user': 'user28', 'type': 'PURCHASE', 'payload': {'value': 951}})]
# 2025-06-05: [(datetime.date(2025, 6, 5), {'id': 143, 'ts': '2025-06-05T10:05:56.472049', 'user': 'user39', 'type': 'LOGOUT', 'payload': {'value': 947}}), (datetime.date(2025, 6, 5), {'id': 317, 'ts': '2025-06-05T11:48:29.472049', 'user': 'user45', 'type': 'LOGIN', 'payload': {'value': 126}}), (datetime.date(2025, 6, 5), {'id': 376, 'ts': '2025-06-05T08:37:36.472049', 'user': 'user22', 'type': 'VIEW', 'payload': {'value': 577}})]
# 2025-06-06: [(datetime.date(2025, 6, 6), {'id': 104, 'ts': '2025-06-06T13:48:49.472049', 'user': 'user35', 'type': 'LOGIN', 'payload': {'value': 489}}), (datetime.date(2025, 6, 6), {'id': 204, 'ts': '2025-06-06T23:02:04.472049', 'user': 'user33', 'type': 'LOGIN', 'payload': {'value': 880}}), (datetime.date(2025, 6, 6), {'id': 315, 'ts': '2025-06-06T15:31:46.472049', 'user': 'user8', 'type': 'VIEW', 'payload': {'value': 45}})]
# 2025-06-07: [(datetime.date(2025, 6, 7), {'id': 7, 'ts': '2025-06-07T22:04:53.472049', 'user': 'user20', 'type': 'PURCHASE', 'payload': {'value': 4}}), (datetime.date(2025, 6, 7), {'id': 240, 'ts': '2025-06-07T14:55:45.472049', 'user': 'user41', 'type': 'LOGOUT', 'payload': {'value': 124}}), (datetime.date(2025, 6, 7), {'id': 305, 'ts': '2025-06-07T09:28:14.472049', 'user': 'user17', 'type': 'CLICK', 'payload': {'value': 920}})]
# 2025-06-08: [(datetime.date(2025, 6, 8), {'id': 17, 'ts': '2025-06-08T00:01:56.472049', 'user': 'user4', 'type': 'CLICK', 'payload': {'value': 912}}), (datetime.date(2025, 6, 8), {'id': 77, 'ts': '2025-06-08T06:30:14.472049', 'user': 'user37', 'type': 'CLICK', 'payload': {'value': 506}}), (datetime.date(2025, 6, 8), {'id': 268, 'ts': '2025-06-08T06:18:53.472049', 'user': 'user1', 'type': 'PURCHASE', 'payload': {'value': 944}})]
# 2025-06-09: [(datetime.date(2025, 6, 9), {'id': 164, 'ts': '2025-06-09T14:53:18.472049', 'user': 'user47', 'type': 'PURCHASE', 'payload': {'value': 255}}), (datetime.date(2025, 6, 9), {'id': 189, 'ts': '2025-06-09T12:06:48.472049', 'user': 'user40', 'type': 'LOGIN', 'payload': {'value': 627}}), (datetime.date(2025, 6, 9), {'id': 381, 'ts': '2025-06-09T12:45:20.472049', 'user': 'user20', 'type': 'LOGOUT', 'payload': {'value': 654}})]
# 2025-06-10: [(datetime.date(2025, 6, 10), {'id': 16, 'ts': '2025-06-10T12:27:12.472049', 'user': 'user39', 'type': 'PURCHASE', 'payload': {'value': 168}}), (datetime.date(2025, 6, 10), {'id': 48, 'ts': '2025-06-10T20:58:05.472049', 'user': 'user41', 'type': 'CLICK', 'payload': {'value': 842}}), (datetime.date(2025, 6, 10), {'id': 168, 'ts': '2025-06-10T15:40:46.472049', 'user': 'user18', 'type': 'LOGOUT', 'payload': {'value': 707}})]
# 2025-06-11: [(datetime.date(2025, 6, 11), {'id': 21, 'ts': '2025-06-11T13:26:55.472049', 'user': 'user30', 'type': 'CLICK', 'payload': {'value': 476}}), (datetime.date(2025, 6, 11), {'id': 75, 'ts': '2025-06-11T20:33:18.472049', 'user': 'user14', 'type': 'LOGOUT', 'payload': {'value': 175}}), (datetime.date(2025, 6, 11), {'id': 145, 'ts': '2025-06-11T21:21:46.472049', 'user': 'user34', 'type': 'VIEW', 'payload': {'value': 341}})]
# 2025-06-12: [(datetime.date(2025, 6, 12), {'id': 203, 'ts': '2025-06-12T03:34:11.472049', 'user': 'user39', 'type': 'LOGOUT', 'payload': {'value': 124}}), (datetime.date(2025, 6, 12), {'id': 302, 'ts': '2025-06-12T01:57:56.472049', 'user': 'user3', 'type': 'PURCHASE', 'payload': {'value': 4}}), (datetime.date(2025, 6, 12), {'id': 515, 'ts': '2025-06-12T02:26:03.472049', 'user': 'user47', 'type': 'LOGIN', 'payload': {'value': 399}})]

# %% [markdown]
# ---
#
# ### Problem 7 – Memoise Payload Normalisation
#
# **Task**
# Memoise Payload Normalisation.
#
# **Hint (constructs to consider)** → functools.lru_cache

# %%
# ⬇️ Write your solution for Problem 7 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 8 – Convert NDJSON to CSV
#
# **Task**
# Convert NDJSON to CSV.
#
# **Hint (constructs to consider)** → json, csv

# %%
# ⬇️ Write your solution for Problem 8 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 9 – Multi‑Key Stable Sort of Events
#
# **Task**
# Multi‑Key Stable Sort of Events.
# > **Task**   Return the first 10 events ordered by `(ts, type, user)` in one pass.
#
#
# **Hint (constructs to consider)** → operator.itemgetter, sorted

# %%
from operator import itemgetter
# ⬇️ Write your solution for Problem 9 below

first_10 = []
evl = list(generate_events(100))
sorted(evl, key=itemgetter("ts", "type", "user"))[:10]
# Out:
# [{'id': 68,
#   'ts': '2025-03-05T01:46:39.063079',
#   'user': 'user26',
#   'type': 'VIEW',
#   'payload': {'value': 336}},
#  {'id': 72,
#   'ts': '2025-03-05T13:30:35.063079',
#   'user': 'user21',
#   'type': 'PURCHASE',
#   'payload': {'value': 917}},
#  {'id': 2,
#   'ts': '2025-03-07T00:40:14.063079',
#   'user': 'user26',
#   'type': 'VIEW',
#   'payload': {'value': 250}},
#  {'id': 52,
#   'ts': '2025-03-07T15:57:19.063079',
#   'user': 'user32',
#   'type': 'CLICK',
#   'payload': {'value': 227}},
#  {'id': 82,
#   'ts': '2025-03-08T21:35:29.063079',
#   'user': 'user22',
#   'type': 'PURCHASE',
#   'payload': {'value': 929}},
#  {'id': 99,
#   'ts': '2025-03-10T23:01:54.063079',
#   'user': 'user46',
#   'type': 'VIEW',
#   'payload': {'value': 277}},
#  {'id': 23,
#   'ts': '2025-03-15T03:13:07.063079',
#   'user': 'user41',
#   'type': 'PURCHASE',
#   'payload': {'value': 112}},
#  {'id': 16,
#   'ts': '2025-03-15T05:10:21.063079',
#   'user': 'user8',
#   'type': 'CLICK',
#   'payload': {'value': 979}},
#  {'id': 35,
#   'ts': '2025-03-15T05:30:54.063079',
#   'user': 'user25',
#   'type': 'CLICK',
#   'payload': {'value': 954}},
#  {'id': 98,
#   'ts': '2025-03-16T00:32:38.063079',
#   'user': 'user8',
#   'type': 'LOGIN',
#   'payload': {'value': 693}}]

# %% [markdown]
# ---
# ### Problem 10 – Finding the Median Event `value` on the Fly   (`heapq` again, but *dual* heaps)
#
# > **Task**   Stream events and be able to query the median of the integer `payload['value']` at any time.
#
# **Hint (constructs to consider)** → heapq, dual‑heap technique

# %%
import heapq
# ⬇️ Write your solution for Problem 10 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 11 – Deduplicate Events by `id`
#
# **Task**
# Deduplicate Events by `id`.
#
# **Hint (constructs to consider)** → set, dict

# %%
# ⬇️ Write your solution for Problem 11 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 12 – Approximate Deduplication with a Bloom‑like Filter
#
# **Task**
# Approximate Deduplication with a Bloom‑like Filter.
#
# **Hint (constructs to consider)** → bytearray, hashlib

# %%
# ⬇️ Write your solution for Problem 12 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 13 – Rolling Average of a Metric (Sliding Window)
#
# **Task**
# Rolling Average of a Metric (Sliding Window).
#
# **Hint (constructs to consider)** → collections.deque

# %%
# ⬇️ Write your solution for Problem 13 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 14 – TTL Cache with Expiration
#
# **Task**
# TTL Cache with Expiration.
#
# **Hint (constructs to consider)** → collections.OrderedDict, datetime

# %%
from operator import itemgetter
from datetime import timedelta
from collections import deque

cache = deque()

# ⬇️ Write your solution for Problem 14 below
TTL = timedelta(days=1)

entries = list(generate_events(500))
entries.sort(key=itemgetter("ts"))
for entry in entries:
    current_entry_time = datetime.fromisoformat(entry["ts"])
    while cache and cache[0][0] + TTL < current_entry_time:
        # evict
        removed = cache.popleft()
    cache.append((datetime.fromisoformat(entry["ts"]), entry))

# %% [markdown]
# ---
#
# ### Problem 15 – Sessionise Events Separated by Idle Time
#
# **Task**
# Sessionise Events Separated by Idle Time.
#
# **Hint (constructs to consider)** → dict, datetime, timedelta

# %%
# ⬇️ Write your solution for Problem 15 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 16 – Peak Concurrent Sessions via Sweep Line
#
# **Task**
# Peak Concurrent Sessions via Sweep Line.
#
# **Hint (constructs to consider)** → sorted list of tuples, heapq or simple counters

# %%
# ⬇️ Write your solution for Problem 16 below
import random
from datetime import datetime, timedelta

def generate_paired_sessions(n_sessions=500):
    now = datetime.now()
    start_base = now - timedelta(days=30)
    for i in range(n_sessions):
        user = f"user{random.randint(1,50)}"
        # pick a random start
        start = start_base + timedelta(seconds=random.randint(0, 30*24*3600))
        # give it a random duration between 1 minute and 4 hours
        end = start + timedelta(seconds=random.randint(60, 4*3600))
        yield {
            "user": user,
            "start_ts": start.isoformat(),
            "end_ts":   end.isoformat()
        }

# %%
time_window = timedelta(minutes=180)
sweep_line = []
for ev in generate_paired_sessions(500):
    sweep_line.append((datetime.fromisoformat(ev["start_ts"]), +1))
    sweep_line.append((datetime.fromisoformat(ev["end_ts"]), -1))

sweep_line.sort(key = lambda x: (x[0], x[1]))
concurrent = 0
max_concur = 0
for ts, delta in sweep_line:
    concurrent += delta
    max_concur = max(max_concur, concurrent)

# %% [markdown]
# ---
#
# ### Problem 17 – Hourly Histograms of Event Types
#
# **Task**
# Hourly Histograms of Event Types.
#
# **Hint (constructs to consider)** → collections.defaultdict, collections.Counter

# %%
from collections import defaultdict, Counter
from datetime import datetime

hist = defaultdict(Counter)

for ev in generate_events(200):
    h = datetime.fromisoformat(ev["ts"]).hour
    t = ev["type"]
    #hist[h][t] += 1
    hist[t].update(t)

# %%
evl[:10]
# Out:
# [(17, 'LOGIN'),
#  (15, 'LOGIN'),
#  (10, 'LOGIN'),
#  (23, 'VIEW'),
#  (19, 'LOGOUT'),
#  (3, 'LOGIN'),
#  (22, 'CLICK'),
#  (11, 'CLICK'),
#  (17, 'LOGOUT'),
#  (3, 'CLICK')]

# %% [markdown]
# ---
#
# ### Problem 18 – Unique User Count per Rolling Window
#
# **Task**
# Unique User Count per Rolling Window.
#
# **Hint (constructs to consider)** → set, collections.deque

# %%
from collections import deque
# ⬇️ Write your solution for Problem 18 below
d = deque()
c = Counter()
WINDOW = 20
for ev in generate_events(200):
    user = ev["user"]
    d.appendleft(user)
    c.update([user])
    if len(d) > WINDOW:
        old_user = d.pop()
        c[old_user] -= 1
        if c[old_user] == 0:
            del c[old_user]        




c
# Out:
# Counter({'user49': 2,
#          'user21': 2,
#          'user11': 2,
#          'user33': 2,
#          'user15': 1,
#          'user38': 1,
#          'user28': 1,
#          'user36': 1,
#          'user44': 1,
#          'user5': 1,
#          'user30': 1,
#          'user19': 1,
#          'user12': 1,
#          'user39': 1,
#          'user41': 1,
#          'user23': 1})

# %% [markdown]
# ---
#
# ### Problem 19 – Throttle Logins per IP Address
#
# **Task**
# Throttle Logins per IP Address.
#
# **Hint (constructs to consider)** → collections.defaultdict, collections.deque

# %%
# ⬇️ Write your solution for Problem 19 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 20 – Maintain Top‑1% Highest payload['value']
#
# **Task**
# Maintain Top‑1% Highest payload['value'].
#
# **Hint (constructs to consider)** → heapq, nlargest / nsmallest

# %%
# ⬇️ Write your solution for Problem 20 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 21 – Detect Sequence: LOGIN → PURCHASE within Δ sec
#
# **Task**
# Detect Sequence: LOGIN → PURCHASE within Δ sec.
#
# **Hint (constructs to consider)** → enum.Enum, dict, datetime

# %%
# ⬇️ Write your solution for Problem 21 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 22 – Parse Apache‑style Logs with Regex
#
# **Task**
# Parse Apache‑style Logs with Regex.
#
# **Hint (constructs to consider)** → re

# %%
# ⬇️ Write your solution for Problem 22 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 23 – Tokenise and Count Words in Message Field
#
# **Task**
# Tokenise and Count Words in Message Field.
#
# **Hint (constructs to consider)** → str.split, collections.Counter

# %%
# ⬇️ Write your solution for Problem 23 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 24 – Bucketise Timestamps into Fixed 5‑min Windows
#
# **Task**
# Bucketise Timestamps into Fixed 5‑min Windows.
#
# **Hint (constructs to consider)** → datetime, integer division

# %%
# ⬇️ Write your solution for Problem 24 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 25 – Rolling Min/Max Queue
#
# **Task**
# Rolling Min/Max Queue.
#
# **Hint (constructs to consider)** → collections.deque (monotonic queue)

# %%
# ⬇️ Write your solution for Problem 25 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 26 – Aggregate After Sorting by User Then Type
#
# **Task**
# Aggregate After Sorting by User Then Type.
#
# **Hint (constructs to consider)** → itertools.groupby

# %%
# ⬇️ Write your solution for Problem 26 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 27 – Detect Repeated Pattern Within User Stream
#
# **Task**
# Detect Repeated Pattern Within User Stream.
#
# **Hint (constructs to consider)** → collections.deque, set

# %%
# ⬇️ Write your solution for Problem 27 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 28 – Join Two Streams on Shared `id`
#
# **Task**
# Join Two Streams on Shared `id`.
#
# **Hint (constructs to consider)** → dict

# %%
# ⬇️ Write your solution for Problem 28 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 29 – Real‑time Leaderboard of Top Buyers
#
# **Task**
# Real‑time Leaderboard of Top Buyers.
#
# **Hint (constructs to consider)** → heapq, dict

# %%
# ⬇️ Write your solution for Problem 29 below
# TODO

# %% [markdown]
# ---
#
# ### Problem 30 – Checkpoint & Replay Events to/from Disk
#
# **Task**
# Checkpoint & Replay Events to/from Disk.
#
# **Hint (constructs to consider)** → json, open/read/write

# %%
# ⬇️ Write your solution for Problem 30 below
# TODO
